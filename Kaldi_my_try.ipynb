# %% [markdown]
# <a href="https://colab.research.google.com/github/MohamedAbuAmira/Natural-Language-Processing-NLP/blob/master/Kaldi_my_try.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/kaldi-asr/kaldi.git
# Out:
# Cloning into 'kaldi'...
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 112294 (delta 0), reused 1 (delta 0), pack-reused 112288
# Receiving objects: 100% (112294/112294), 119.71 MiB | 32.24 MiB/s, done.
# Resolving deltas: 100% (86974/86974), done.

# %%
# !sudo apt install -qq g++ automake autoconf libtool subversion gawk
# Out:
# g++ is already the newest version (4:7.4.0-1ubuntu2.3).
# g++ set to manually installed.
# The following additional packages will be installed:
#   autotools-dev file libapr1 libaprutil1 libmagic-mgc libmagic1 libserf-1-1
#   libsigsegv2 libsvn1 m4
# Suggested packages:
#   autoconf-archive gnu-standards autoconf-doc gettext gawk-doc libtool-doc
#   gcj-jdk m4-doc db5.3-util libapache2-mod-svn subversion-tools
# The following NEW packages will be installed:
#   autoconf automake autotools-dev file gawk libapr1 libaprutil1 libmagic-mgc
#   libmagic1 libserf-1-1 libsigsegv2 libsvn1 libtool m4 subversion
# 0 upgraded, 15 newly installed, 0 to remove and 21 not upgraded.
# Need to get 4,189 kB of archives.
# After this operation, 22.0 MB of additional disk space will be used.
# debconf: unable to initialize frontend: Dialog
# ...

# %%
# !sudo apt install libatlas-base-dev

# !sudo apt install libblas-dev

# !sudo apt install liblapack3
# !sudo apt install liblapack-dev

# !sudo apt install libopenblas-base 
# !sudo apt install libopenblas-dev 

# !sudo apt install liblapacke-dev 

# !sudo apt install liblapack-dev
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libatlas-base-dev is already the newest version (3.10.3-5).
# 0 upgraded, 0 newly installed, 0 to remove and 21 not upgraded.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   libblas3
# Suggested packages:
#   liblapack-doc
# The following NEW packages will be installed:
#   libblas-dev libblas3
# 0 upgraded, 2 newly installed, 0 to remove and 21 not upgraded.
# Need to get 283 kB of archives.
# After this operation, 1,537 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/main amd64 libblas3 amd64 3.7.1-4ubuntu1 [140 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/main amd64 libblas-dev amd64 3.7.1-4ubuntu1 [143 kB]
# Fetched 283 kB in 1s (300 kB/s)
# debconf: unable to initialize frontend: Dialog
# ...

# %%
# !sudo apt-get install sox
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   libopencore-amrnb0 libopencore-amrwb0 libsox-fmt-alsa libsox-fmt-base
#   libsox3
# Suggested packages:
#   libsox-fmt-all
# The following NEW packages will be installed:
#   libopencore-amrnb0 libopencore-amrwb0 libsox-fmt-alsa libsox-fmt-base
#   libsox3 sox
# 0 upgraded, 6 newly installed, 0 to remove and 21 not upgraded.
# Need to get 507 kB of archives.
# After this operation, 1,503 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libopencore-amrnb0 amd64 0.1.3-2.1 [92.0 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libopencore-amrwb0 amd64 0.1.3-2.1 [45.8 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libsox3 amd64 14.4.2-3ubuntu0.18.04.1 [226 kB]
# ...

# %%
import os
os.chdir('/content/kaldi/tools')

# %%
# !./extras/install_mkl.sh
# Out:
# ./extras/install_mkl.sh: Your system is using debian-style package management.
# + apt-get update
# Ign:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Ign:3 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Get:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release [697 B]
# Hit:5 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Get:6 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release.gpg [836 B]
# Get:7 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Hit:8 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:9 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease [15.9 kB]
# ...

# %%
# !./extras/install_irstlm.sh
# Out:
# ****() Installing IRSTLM
# Cloning into 'irstlm'...
# remote: Enumerating objects: 1781, done.
# remote: Total 1781 (delta 0), reused 0 (delta 0), pack-reused 1781
# Receiving objects: 100% (1781/1781), 3.54 MiB | 21.08 MiB/s, done.
# Resolving deltas: 100% (1187/1187), done.
# patching file configure.ac
# patching file src/Makefile.am
# Calling /usr/bin/autoreconf
# configure.ac:10: warning: LT_INIT was called before AM_PROG_AR
# /usr/share/aclocal-1.15/ar-lib.m4:13: AM_PROG_AR is expanded from...
# configure.ac:10: the top level
# configure.ac:10: warning: AC_PROG_LIBTOOL was called before AM_PROG_AR
# /usr/share/aclocal-1.15/ar-lib.m4:13: AM_PROG_AR is expanded from...
# configure.ac:10: the top level
# configure.ac:10: warning: LT_INIT was called before AM_PROG_AR
# /usr/share/aclocal-1.15/ar-lib.m4:13: AM_PROG_AR is expanded from...
# configure.ac:10: the top level
# configure.ac:10: warning: AC_PROG_LIBTOOL was called before AM_PROG_AR
# ...

# %%
# !./extras/install_openblas.sh
# Out:
# Streaming output truncated to the last 5000 lines.
# gfortran -O2 -Wall -frecursive -fno-optimize-sibling-calls -m64 -fPIC -mavx2 -c -o ztplqt.o ztplqt.f
# gfortran -O2 -Wall -frecursive -fno-optimize-sibling-calls -m64 -fPIC -mavx2 -c -o ztplqt2.o ztplqt2.f
# gfortran -O2 -Wall -frecursive -fno-optimize-sibling-calls -m64 -fPIC -mavx2 -c -o ztpmlqt.o ztpmlqt.f
# gfortran -O2 -Wall -frecursive -fno-optimize-sibling-calls -m64 -fPIC -mavx2 -c -o zgelqt.o zgelqt.f
# gfortran -O2 -Wall -frecursive -fno-optimize-sibling-calls -m64 -fPIC -mavx2 -c -o zgelqt3.o zgelqt3.f
# gfortran -O2 -Wall -frecursive -fno-optimize-sibling-calls -m64 -fPIC -mavx2 -c -o zgemlqt.o zgemlqt.f
# gfortran -O2 -Wall -frecursive -fno-optimize-sibling-calls -m64 -fPIC -mavx2 -c -o zgetsls.o zgetsls.f
# zgetsls.f:276:0:
#
#          WORK( 1 ) = DBLE( WSIZEO )
#
# ...
# gfortran -O2 -Wall -frecursive -fno-optimize-sibling-calls -m64 -fPIC -mavx2 -c -o zgeqr.o zgeqr.f
# ...

# %%
# !./extras/check_dependencies.sh
# Out:
# ./extras/check_dependencies.sh: WARNING python 2.7 is not the default python. We fixed this by adding a correct symlink more prominently on the path.
#  ... If you really want to use python 3.6.9 as default, add an empty file /content/kaldi/tools/python/.use_default_python and run this script again.
# ./extras/check_dependencies.sh: all OK.

# %%
# !make -j 4
# Out:
# extras/check_dependencies.sh
# if [ -d "" ]; then \
# 	cp -p "/sph2pipe_v2.5.tar.gz" .; \
# else \
# 	wget -T 10 -t 3 https://www.openslr.org/resources/3/sph2pipe_v2.5.tar.gz || \
# 	wget -T 10 -c https://sourceforge.net/projects/kaldi/files/sph2pipe_v2.5.tar.gz; \
# fi
# if [ -d "" ]; then \
# 	cp -p "/sctk-2.4.10-20151007-1312Z.tar.bz2" .; \
# else \
# 	wget -T 10 https://www.openslr.org/resources/4/sctk-2.4.10-20151007-1312Z.tar.bz2; \
# fi
# if [ -d "" ]; then \
# 	cp -p "/openfst-1.6.7.tar.gz" .; \
# else \
# 	wget -T 10 -t 1 http://www.openfst.org/twiki/pub/FST/FstDownload/openfst-1.6.7.tar.gz || \
# 	wget -T 10 -t 3 -c https://www.openslr.org/resources/2/openfst-1.6.7.tar.gz; \
# fi
# --2020-10-02 00:12:56--  https://www.openslr.org/resources/3/sph2pipe_v2.5.tar.gz
# --2020-10-02 00:12:56--  http://www.openfst.org/twiki/pub/FST/FstDownload/openfst-1.6.7.tar.gz
# ...

# %%
os.chdir("/content/kaldi/src")

# %%
# !./configure
# Out:
# Configuring KALDI to use MKL.
# Backing up kaldi.mk to kaldi.mk.bak ...
# Checking compiler g++ ...
# Checking OpenFst library in /content/kaldi/tools/openfst-1.6.7 ...
# Checking cub library in /content/kaldi/tools/cub-1.8.0 ...
# Performing OS specific configuration ...
# On Linux: Checking for linear algebra header files ...
# Configuring MKL library directory: Found: /opt/intel/mkl/lib/intel64
# MKL configured libs: -L/opt/intel/mkl/lib/intel64 -Wl,-rpath=/opt/intel/mkl/lib/intel64 -lmkl_intel_lp64 -lmkl_core -lmkl_sequential -ldl -lpthread -lm
# MKL include directory: -I/opt/intel/mkl/include
# Using Intel MKL as the linear algebra library.
# Intel(R) Math Kernel Library Version 2020.0.0 Product Build 20191122 for Intel(R) 64 architecture applications
# Successfully configured for Linux with MKL libs from /opt/intel/mkl
# Using CUDA toolkit /usr/local/cuda (nvcc compiler and runtime libraries)
# INFO: Configuring Kaldi not to link with Speex. Don't worry, it's only needed if
# ...

# %%
# !make depend -j 4
# Out:
# make -C base/ depend
# make -C matrix/ depend
# make -C util/ depend
# make -C feat/ depend
# make[1]: Entering directory '/content/kaldi/src/base'
# make[1]: Entering directory '/content/kaldi/src/util'
# make[1]: Entering directory '/content/kaldi/src/feat'
# make[1]: Entering directory '/content/kaldi/src/matrix'
# rm -f .depend.mk
# rm -f .depend.mk
# rm -f .depend.mk
# ...

# %%
# !make -j 4
# Out:
# test -d  || mkdir
# The version of configure script matches kaldi.mk version. Good.
# make -C base
# make[1]: Entering directory '/content/kaldi/src/base'
# g++ -std=c++11 -I.. -isystem /content/kaldi/tools/openfst-1.6.7/include -O1  -Wall -Wno-sign-compare -Wno-unused-local-typedefs -Wno-deprecated-declarations -Winit-self -DKALDI_DOUBLEPRECISION=0 -DHAVE_EXECINFO_H=1 -DHAVE_CXXABI_H -DHAVE_MKL -I/opt/intel/mkl/include -m64 -msse -msse2 -pthread -g -DHAVE_CUDA -I/usr/local/cuda/include -fPIC -pthread -isystem /content/kaldi/tools/openfst-1.6.7/include   -c -o kaldi-math.o kaldi-math.cc
# ...

# %%
os.chdir("/content")

# %%
# %%bash
#
# cd /content/kaldi/egs/yesno/s5
# ./run.sh
# Out:
# waves_yesno/
# waves_yesno/1_0_0_0_0_0_1_1.wav
# waves_yesno/1_1_0_0_1_0_1_0.wav
# waves_yesno/1_0_1_1_1_1_0_1.wav
# waves_yesno/1_1_1_1_0_1_0_0.wav
# waves_yesno/0_0_1_1_1_0_0_0.wav
# waves_yesno/0_1_1_1_1_1_1_1.wav
# waves_yesno/0_1_0_1_1_1_0_0.wav
# waves_yesno/1_0_1_1_1_0_1_0.wav
# waves_yesno/1_0_0_1_0_1_1_1.wav
# waves_yesno/0_0_1_0_1_0_0_0.wav
# waves_yesno/0_1_0_1_1_0_1_0.wav
# waves_yesno/0_0_1_1_0_1_1_0.wav
# waves_yesno/1_0_0_0_1_0_0_1.wav
# waves_yesno/1_1_0_1_1_1_1_0.wav
# waves_yesno/0_0_1_1_1_1_0_0.wav
# waves_yesno/1_1_0_0_1_1_1_0.wav
# waves_yesno/0_0_1_1_0_1_1_1.wav
# waves_yesno/1_1_0_1_0_1_1_0.wav
# waves_yesno/0_1_0_0_0_1_1_0.wav
# waves_yesno/0_0_0_1_0_0_0_1.wav
# waves_yesno/0_0_1_0_1_0_1_1.wav
# waves_yesno/0_0_1_0_0_0_1_0.wav
# waves_yesno/1_1_0_1_1_0_0_1.wav
# waves_yesno/0_1_1_1_0_1_0_1.wav
# waves_yesno/0_1_1_1_0_0_0_0.wav
# waves_yesno/README~
# waves_yesno/0_1_0_0_0_1_0_0.wav
# waves_yesno/1_0_0_0_0_0_0_1.wav
# waves_yesno/1_1_0_1_1_0_1_1.wav
# ...

# %%
import tarfile
import requests

# %%
# !pip3 install vosk
# Out:
# ...
#      |████████████████████████████████| 7.4MB 4.4MB/s
# ...

# %%
#os.chdir("/content")

# %%
# !git clone https://github.com/alphacep/vosk-api.git
# Out:
# Cloning into 'vosk-api'...
# remote: Enumerating objects: 98, done.
# remote: Counting objects: 100% (98/98), done.
# remote: Compressing objects: 100% (71/71), done.
# remote: Total 1223 (delta 42), reused 59 (delta 22), pack-reused 1125
# Receiving objects: 100% (1223/1223), 432.53 KiB | 16.02 MiB/s, done.
# Resolving deltas: 100% (700/700), done.

# %%
# %%bash
#
# apt-get remove swig
# apt-get install swig3.0
# ln -s /usr/bin/swig3.0 /usr/bin/swig
# Out:
# Reading package lists...
# Building dependency tree...
# Reading state information...
# Package 'swig' is not installed, so not removed
# 0 upgraded, 0 newly installed, 0 to remove and 27 not upgraded.
# Reading package lists...
# Building dependency tree...
# Reading state information...
# Suggested packages:
#   swig3.0-examples swig3.0-doc
# The following NEW packages will be installed:
#   swig3.0
# 0 upgraded, 1 newly installed, 0 to remove and 27 not upgraded.
# Need to get 1,094 kB of archives.
# After this operation, 5,499 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 swig3.0 amd64 3.0.12-1 [1,094 kB]
# Fetched 1,094 kB in 1s (922 kB/s)
# Selecting previously unselected package swig3.0.
# (Reading database ... 147691 files and directories currently installed.)
# Preparing to unpack .../swig3.0_3.0.12-1_amd64.deb ...
# Unpacking swig3.0 (3.0.12-1) ...
# Setting up swig3.0 (3.0.12-1) ...
# ...

# %%
# !sudo apt-get install python3-dev
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# python3-dev is already the newest version (3.6.7-1~18.04).
# 0 upgraded, 0 newly installed, 0 to remove and 27 not upgraded.

# %%
# %%bash
# export KALDI_ROOT='/content/kaldi'
# cd /content/vosk-api/python
# python3 setup.py install
# Out:
# running install
# running bdist_egg
# running egg_info
# writing vosk.egg-info/PKG-INFO
# writing dependency_links to vosk.egg-info/dependency_links.txt
# writing top-level names to vosk.egg-info/top_level.txt
# writing manifest file 'vosk.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# running build_ext
# building 'vosk._vosk' extension
# swigging vosk/vosk.i to vosk/vosk_wrap.cpp
# swig -python -outdir vosk -c++ -o vosk/vosk_wrap.cpp vosk/vosk.i
# x86_64-linux-gnu-gcc -pthread -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -DFST_NO_DYNAMIC_LINKING=1 -I/content/kaldi/src -I/content/kaldi/tools/openfst/include -Ivosk -I/usr/include/python3.6m -c vosk/kaldi_recognizer.cc -o build/temp.linux-x86_64-3.6/vosk/kaldi_recognizer.o -std=c++11 -Wno-sign-compare -Wno-unused-variable -Wno-unused-local-typedefs
# ...

# %%
# %%bash
# cd vosk-api/python/example
# wget https://alphacephei.com/kaldi/models/vosk-model-small-en-us-0.3.zip
# unzip vosk-model-small-en-us-0.3.zip
# mv vosk-model-small-en-us-0.3 model
# python3 ./test_simple.py test.wav
# Out:
# Archive:  vosk-model-small-en-us-0.3.zip
#    creating: vosk-model-small-en-us-0.3/
#   inflating: vosk-model-small-en-us-0.3/final.mdl
#   inflating: vosk-model-small-en-us-0.3/disambig_tid.int
#   inflating: vosk-model-small-en-us-0.3/Gr.fst
#    creating: vosk-model-small-en-us-0.3/ivector/
#   inflating: vosk-model-small-en-us-0.3/ivector/global_cmvn.stats
#   inflating: vosk-model-small-en-us-0.3/ivector/online_cmvn.conf
#   inflating: vosk-model-small-en-us-0.3/ivector/splice.conf
#   inflating: vosk-model-small-en-us-0.3/ivector/final.ie
#   inflating: vosk-model-small-en-us-0.3/ivector/final.dubm
#   inflating: vosk-model-small-en-us-0.3/ivector/final.mat
#   inflating: vosk-model-small-en-us-0.3/HCLr.fst
#  extracting: vosk-model-small-en-us-0.3/mfcc.conf
#   inflating: vosk-model-small-en-us-0.3/word_boundary.int
# {
#   "partial" : ""
# }
# {
#   "partial" : ""
# }
# {
#   "partial" : ""
# }
# {
#   "partial" : ""
# }
# {
#   "partial" : ""
# }
# {
#   "partial" : ""
# }
# ...

# %%
# %%bash
# cd vosk-api/python/example
# wget https://alphacephei.com/vosk/models/vosk-model-ar-mgb2-0.4.zip
# unzip vosk-model-ar-mgb2-0.4.zip
# mv vosk-model-ar-mgb2-0.4 model
# python3 ./test_simple.py test.wav

# %%
# %%bash
# wget https://alphacephei.com/vosk/models/vosk-model-ar-mgb2-0.4.zip
# unzip vosk-model-ar-mgb2-0.4.zip
# Out:
# Archive:  vosk-model-ar-mgb2-0.4.zip
#    creating: vosk-model-ar-mgb2-0.4/
#    creating: vosk-model-ar-mgb2-0.4/am/
#   inflating: vosk-model-ar-mgb2-0.4/am/final.mdl
#   inflating: vosk-model-ar-mgb2-0.4/am/tree
#    creating: vosk-model-ar-mgb2-0.4/ivector/
#   inflating: vosk-model-ar-mgb2-0.4/ivector/final.dubm
#   inflating: vosk-model-ar-mgb2-0.4/ivector/final.ie
#   inflating: vosk-model-ar-mgb2-0.4/ivector/final.mat
#   inflating: vosk-model-ar-mgb2-0.4/ivector/splice.conf
#  extracting: vosk-model-ar-mgb2-0.4/ivector/final.ie.id
#   inflating: vosk-model-ar-mgb2-0.4/ivector/global_cmvn.stats
#   inflating: vosk-model-ar-mgb2-0.4/ivector/online_cmvn.conf
#    creating: vosk-model-ar-mgb2-0.4/scripts/
#   inflating: vosk-model-ar-mgb2-0.4/scripts/buckwalter2unicode.py
#   inflating: vosk-model-ar-mgb2-0.4/README
#    creating: vosk-model-ar-mgb2-0.4/conf/
#   inflating: vosk-model-ar-mgb2-0.4/conf/mfcc.conf
#   inflating: vosk-model-ar-mgb2-0.4/conf/model.conf
# ...

# %%
# %%bash
# cd vosk-api/python/example
# wget https://alphacephei.com/vosk/models/vosk-model-ar-mgb2-0.4.zip
# unzip vosk-model-ar-mgb2-0.4.zip
# mv vosk-model-ar-mgb2-0.4 model
# python3 ./test_simple.py test.wav
# Out:
# Archive:  vosk-model-ar-mgb2-0.4.zip
#    creating: vosk-model-ar-mgb2-0.4/
#    creating: vosk-model-ar-mgb2-0.4/am/
#   inflating: vosk-model-ar-mgb2-0.4/am/final.mdl
#   inflating: vosk-model-ar-mgb2-0.4/am/tree
#    creating: vosk-model-ar-mgb2-0.4/ivector/
#   inflating: vosk-model-ar-mgb2-0.4/ivector/final.dubm
#   inflating: vosk-model-ar-mgb2-0.4/ivector/final.ie
#   inflating: vosk-model-ar-mgb2-0.4/ivector/final.mat
#   inflating: vosk-model-ar-mgb2-0.4/ivector/splice.conf
#  extracting: vosk-model-ar-mgb2-0.4/ivector/final.ie.id
#   inflating: vosk-model-ar-mgb2-0.4/ivector/global_cmvn.stats
#   inflating: vosk-model-ar-mgb2-0.4/ivector/online_cmvn.conf
#    creating: vosk-model-ar-mgb2-0.4/scripts/
#   inflating: vosk-model-ar-mgb2-0.4/scripts/buckwalter2unicode.py
#   inflating: vosk-model-ar-mgb2-0.4/README
#    creating: vosk-model-ar-mgb2-0.4/conf/
#   inflating: vosk-model-ar-mgb2-0.4/conf/mfcc.conf
#   inflating: vosk-model-ar-mgb2-0.4/conf/model.conf
# ...

# %%
import shutil

# %%
#shutil.rmtree("/content/vosk-api/python/example/model___")

# %%
# %%bash
# wget http://ar.arabicspeechcorpus.com/arabic-speech-corpus.zip
# unzip arabic-speech-corpus.zip

# %%
# !mv /content/arabic-speech-corpus/wav/test1.wav /content

# %%
# %%bash
# cd vosk-api/python/example
# python3 ./test_simple.py test1.wav
# Out:
# {
#   "partial" : ""
# }
# {
#   "partial" : ""
# }
# {
#   "partial" : ""
# }
# {
#   "partial" : ""
# }
# {
#   "partial" : ""
# }
# {
#   "partial" : ""
# }
# {
#   "partial" : ""
# }
# {
#   "partial" : ""
# }
# {
#   "partial" : ""
# }
# {
#   "partial" : ""
# }
# {
#   "partial" : ""
# }
# {
#   "partial" : ""
# }
# {
#   "partial" : "ورجحت"
# }
# {
#   "partial" : "ورجحت"
# }
# {
#   "partial" : "ورجحت"
# }
# {
#   "partial" : "ورجح التقرير"
# }
# {
#   "partial" : "ورجح التقرير"
# }
# {
#   "partial" : "ورجح التقرير"
# }
# {
#   "partial" : "ورجح التقرير"
# }
# {
#   "partial" : "ورجح التقرير"
# }
# {
#   "partial" : "ورجح التقرير"
# }
# {
#   "partial" : "ورجح التقرير"
# }
# {
#   "partial" : "ورجح التقرير الذي"
# }
# {
#   "partial" : "ورجح التقرير الذي"
# }
# {
#   "partial" : "ورجح التقرير الذي"
# }
# {
#   "partial" : "ورجح التقرير الذي"
# }
# {
#   "partial" : "ورجح التقرير الذي"
# }
# {
#   "partial" : "ورجح التقرير الذي أعده"
# }
# {
# ...

# %%
# %%bash
# head /content/vosk-model-ar-mgb2-0.4/graph/words.txt
# Out:
# <eps> 0
# ش 1
# ششانتو 2
# ششمال 3
# ششن 4
# ششناق 5
# ششنق 6
# ششنية 7
# ششتاري 8
# ششتر 9
